# %% [markdown]
# # Crear diccionario

# %%
import random as rn

rn.seed(2023)

# %%
# Los nombres
nombres = ['ROBERTO', 'MIGUEL', 'GUILLERMO', 'DAVID', 'RICARDO', 'JOSÉ', 'CARLOS', "TOMÁS", 'CRISTIAN', 'DANIEL', 
           'MATEO', 'ANTONIO', 'DONALD', 'MARCO', 'PABLO', 'ANDRES', 'JORGE', 'RUBEN', 'KEVIN', 'RANDY', 
           'BRYANT', 'EDUARDO', 'OSCAR', 'LUIS', 'ALFREDO', 
           'MARY', 'PATRICIA', 'JENNY', 'ELIZABETH', 'LINDA', 'BARBARA', 'SUSANA', 'JESSICA', 'MARGARITA', 'SARA', 
           'KAREN', 'NANCY', 'ELISA', 'BETY', 'LUCY', 'GUILLE', 'FATIMA', 'LEO', 'DONNA', 'EMILIA', 
           'CAROLINA', 'MICHELLE', 'AMANDA', 'GLORIA', 'ADRIANA']
generos = ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
           'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
           'M', 'M','M', 'M', 'M',
           'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F',
           'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F',
           'F', 'F', 'F', 'F', 'F']


carreras = ["SISTEMAS", "TIC", "INFORMATICA", "ARQUITECTURA", "QUIMICA"]

clases = ["ALTA", "MEDIA", "BAJA"]

print(len(nombres))
print(len(generos))
print(carreras)
print(clases)
# Out:
# 50
# 50
# ['SISTEMAS', 'TIC', 'INFORMATICA', 'ARQUITECTURA', 'QUIMICA']
# ['ALTA', 'MEDIA', 'BAJA']

# %%
# Crear llaves

# Crear el diccionario con claves aleatorias y valores aleatorios
personas = {}
for i in range(100):
    clave = rn.randint(1000, 2000)
    
    # Nombre y genero aleatorio
    n = rn.randint(0, 49)
    nombre = nombres[n]
    genero = generos[n]
    
    # edad aleatorio
    edad = rn.randint(18, 25)
    
    # carrera
    n = rn.randint(0, 4)
    carrera = carreras[n]
    
    # promedio
    # edad aleatorio
    promedio = rn.randint(70, 100) 
    
    # clase economica
        # carrera
    n = rn.randint(0, 2)
    clase = clases[n]
    
    personas[clave] = {"nombre": nombre, "edad": edad, "carrera": carrera, "promedio": promedio, "clase":clase}

# Imprimir el diccionario
print(personas)
# Out:
# {1392: {'nombre': 'EMILIA', 'edad': 25, 'carrera': 'ARQUITECTURA', 'promedio': 80, 'clase': 'BAJA'}, 1584: {'nombre': 'EDUARDO', 'edad': 19, 'carrera': 'SISTEMAS', 'promedio': 90, 'clase': 'MEDIA'}, 1858: {'nombre': 'EMILIA', 'edad': 22, 'carrera': 'TIC', 'promedio': 77, 'clase': 'ALTA'}, 1652: {'nombre': 'MIGUEL', 'edad': 21, 'carrera': 'INFORMATICA', 'promedio': 72, 'clase': 'BAJA'}, 1129: {'nombre': 'MARY', 'edad': 24, 'carrera': 'ARQUITECTURA', 'promedio': 80, 'clase': 'ALTA'}, 1922: {'nombre': 'ELIZABETH', 'edad': 23, 'carrera': 'QUIMICA', 'promedio': 72, 'clase': 'ALTA'}, 1550: {'nombre': 'LINDA', 'edad': 25, 'carrera': 'SISTEMAS', 'promedio': 95, 'clase': 'ALTA'}, 1586: {'nombre': 'ANDRES', 'edad': 19, 'carrera': 'QUIMICA', 'promedio': 72, 'clase': 'ALTA'}, 1143: {'nombre': 'ALFREDO', 'edad': 25, 'carrera': 'TIC', 'promedio': 89, 'clase': 'BAJA'}, 1186: {'nombre': 'SARA', 'edad': 21, 'carrera': 'INFORMATICA', 'promedio': 97, 'clase': 'MEDIA'}, 1837: {'nombre': 'GUILLE', 'edad'
# ...

# %%
personas = {1392: {'nombre': 'EMILIA', 'edad': 25, 'carrera': 'ARQUITECTURA', 'promedio': 80, 'clase': 'BAJA'}, 1584: {'nombre': 'EDUARDO', 'edad': 19, 'carrera': 'SISTEMAS', 'promedio': 90, 'clase': 'MEDIA'}, 1858: {'nombre': 'EMILIA', 'edad': 22, 'carrera': 'TIC', 'promedio': 77, 'clase': 'ALTA'}, 1652: {'nombre': 'MIGUEL', 'edad': 21, 'carrera': 'INFORMATICA', 'promedio': 72, 'clase': 'BAJA'}, 1129: {'nombre': 'MARY', 'edad': 24, 'carrera': 'ARQUITECTURA', 'promedio': 80, 'clase': 'ALTA'}, 1922: {'nombre': 'ELIZABETH', 'edad': 23, 'carrera': 'QUIMICA', 'promedio': 72, 'clase': 'ALTA'}, 1550: {'nombre': 'LINDA', 'edad': 25, 'carrera': 'SISTEMAS', 'promedio': 95, 'clase': 'ALTA'}, 1586: {'nombre': 'ANDRES', 'edad': 19, 'carrera': 'QUIMICA', 'promedio': 72, 'clase': 'ALTA'}, 1143: {'nombre': 'ALFREDO', 'edad': 25, 'carrera': 'TIC', 'promedio': 89, 'clase': 'BAJA'}, 1186: {'nombre': 'SARA', 'edad': 21, 'carrera': 'INFORMATICA', 'promedio': 97, 'clase': 'MEDIA'}, 1837: {'nombre': 'GUILLE', 'edad': 19, 'carrera': 'QUIMICA', 'promedio': 93, 'clase': 'ALTA'}, 1383: {'nombre': 'BARBARA', 'edad': 20, 'carrera': 'INFORMATICA', 'promedio': 72, 'clase': 'BAJA'}, 1913: {'nombre': 'MARY', 'edad': 23, 'carrera': 'INFORMATICA', 'promedio': 80, 'clase': 'MEDIA'}, 1832: {'nombre': 'CRISTIAN', 'edad': 20, 'carrera': 'ARQUITECTURA', 'promedio': 72, 'clase': 'BAJA'}, 1365: {'nombre': 'KAREN', 'edad': 21, 'carrera': 'TIC', 'promedio': 86, 'clase': 'MEDIA'}, 1570: {'nombre': 'FATIMA', 'edad': 19, 'carrera': 'SISTEMAS', 'promedio': 78, 'clase': 'ALTA'}, 1987: {'nombre': 'ROBERTO', 'edad': 22, 'carrera': 'TIC', 'promedio': 92, 'clase': 'ALTA'}, 1173: {'nombre': 'FATIMA', 'edad': 22, 'carrera': 'ARQUITECTURA', 'promedio': 86, 'clase': 'BAJA'}, 1096: {'nombre': 'JENNY', 'edad': 25, 'carrera': 'ARQUITECTURA', 'promedio': 72, 'clase': 'BAJA'}, 1667: {'nombre': 'BRYANT', 'edad': 23, 'carrera': 'SISTEMAS', 'promedio': 100, 'clase': 'ALTA'}, 1497: {'nombre': 'BARBARA', 'edad': 25, 'carrera': 'SISTEMAS', 'promedio': 100, 'clase': 'BAJA'}, 1592: {'nombre': 'ALFREDO', 'edad': 21, 'carrera': 'SISTEMAS', 'promedio': 83, 'clase': 'BAJA'}, 1601: {'nombre': 'LEO', 'edad': 21, 'carrera': 'INFORMATICA', 'promedio': 97, 'clase': 'ALTA'}, 1198: {'nombre': 'CARLOS', 'edad': 19, 'carrera': 'INFORMATICA', 'promedio': 99, 'clase': 'ALTA'}, 1283: {'nombre': 'MARCO', 'edad': 18, 'carrera': 'INFORMATICA', 'promedio': 71, 'clase': 'MEDIA'}, 1927: {'nombre': 'LUIS', 'edad': 24, 'carrera': 'SISTEMAS', 'promedio': 92, 'clase': 'BAJA'}, 2000: {'nombre': 'EDUARDO', 'edad': 22, 'carrera': 'SISTEMAS', 'promedio': 92, 'clase': 'MEDIA'}, 1599: {'nombre': 'GLORIA', 'edad': 19, 'carrera': 'INFORMATICA', 'promedio': 79, 'clase': 'ALTA'}, 1225: {'nombre': 'MARGARITA', 'edad': 21, 'carrera': 'INFORMATICA', 'promedio': 79, 'clase': 'ALTA'}, 1161: {'nombre': 'SARA', 'edad': 19, 'carrera': 'SISTEMAS', 'promedio': 95, 'clase': 'ALTA'}, 1870: {'nombre': 'CRISTIAN', 'edad': 21, 'carrera': 'SISTEMAS', 'promedio': 87, 'clase': 'MEDIA'}, 1605: {'nombre': 'PABLO', 'edad': 18, 'carrera': 'QUIMICA', 'promedio': 89, 'clase': 'ALTA'}, 1704: {'nombre': 'BRYANT', 'edad': 25, 'carrera': 'ARQUITECTURA', 'promedio': 93, 'clase': 'MEDIA'}, 1717: {'nombre': 'BARBARA', 'edad': 19, 'carrera': 'QUIMICA', 'promedio': 76, 'clase': 'ALTA'}, 1552: {'nombre': 'MARY', 'edad': 20, 'carrera': 'SISTEMAS', 'promedio': 97, 'clase': 'ALTA'}, 1842: {'nombre': 'BARBARA', 'edad': 20, 'carrera': 'ARQUITECTURA', 'promedio': 88, 'clase': 'MEDIA'}, 1742: {'nombre': 'MICHELLE', 'edad': 23, 'carrera': 'TIC', 'promedio': 89, 'clase': 'ALTA'}, 1672: {'nombre': 'JENNY', 'edad': 19, 'carrera': 'TIC', 'promedio': 77, 'clase': 'ALTA'}, 1408: {'nombre': 'ELIZABETH', 'edad': 20, 'carrera': 'TIC', 'promedio': 98, 'clase': 'ALTA'}, 1097: {'nombre': 'LINDA', 'edad': 18, 'carrera': 'QUIMICA', 'promedio': 93, 'clase': 'ALTA'}, 1329: {'nombre': 'OSCAR', 'edad': 25, 'carrera': 'ARQUITECTURA', 'promedio': 86, 'clase': 'ALTA'}, 1628: {'nombre': 'KAREN', 'edad': 21, 'carrera': 'ARQUITECTURA', 'promedio': 82, 'clase': 'BAJA'}, 1504: {'nombre': 'ALFREDO', 'edad': 22, 'carrera': 'INFORMATICA', 'promedio': 74, 'clase': 'ALTA'}, 1582: {'nombre': 'RANDY', 'edad': 20, 'carrera': 'QUIMICA', 'promedio': 95, 'clase': 'ALTA'}, 1450: {'nombre': 'JORGE', 'edad': 25, 'carrera': 'INFORMATICA', 'promedio': 94, 'clase': 'BAJA'}, 1064: {'nombre': 'MARGARITA', 'edad': 24, 'carrera': 'INFORMATICA', 'promedio': 95, 'clase': 'ALTA'}, 1120: {'nombre': 'KEVIN', 'edad': 18, 'carrera': 'QUIMICA', 'promedio': 72, 'clase': 'BAJA'}, 1544: {'nombre': 'PABLO', 'edad': 19, 'carrera': 'TIC', 'promedio': 99, 'clase': 'ALTA'}, 1260: {'nombre': 'ELISA', 'edad': 23, 'carrera': 'QUIMICA', 'promedio': 97, 'clase': 'BAJA'}, 1410: {'nombre': 'ANTONIO', 'edad': 23, 'carrera': 'SISTEMAS', 'promedio': 88, 'clase': 'MEDIA'}, 1701: {'nombre': 'AMANDA', 'edad': 22, 'carrera': 'SISTEMAS', 'promedio': 100, 'clase': 'BAJA'}, 1400: {'nombre': 'MIGUEL', 'edad': 18, 'carrera': 'ARQUITECTURA', 'promedio': 74, 'clase': 'MEDIA'}, 1573: {'nombre': 'RUBEN', 'edad': 25, 'carrera': 'SISTEMAS', 'promedio': 93, 'clase': 'ALTA'}, 1924: {'nombre': 'RICARDO', 'edad': 25, 'carrera': 'SISTEMAS', 'promedio': 71, 'clase': 'ALTA'}, 1880: {'nombre': 'LEO', 'edad': 21, 'carrera': 'INFORMATICA', 'promedio': 82, 'clase': 'BAJA'}, 1614: {'nombre': 'ALFREDO', 'edad': 25, 'carrera': 'TIC', 'promedio': 71, 'clase': 'BAJA'}, 1732: {'nombre': 'OSCAR', 'edad': 22, 'carrera': 'INFORMATICA', 'promedio': 93, 'clase': 'ALTA'}, 1569: {'nombre': 'EMILIA', 'edad': 21, 'carrera': 'TIC', 'promedio': 85, 'clase': 'BAJA'}, 1278: {'nombre': 'JORGE', 'edad': 22, 'carrera': 'ARQUITECTURA', 'promedio': 87, 'clase': 'BAJA'}, 1624: {'nombre': 'CRISTIAN', 'edad': 20, 'carrera': 'ARQUITECTURA', 'promedio': 85, 'clase': 'ALTA'}, 1364: {'nombre': 'LINDA', 'edad': 19, 'carrera': 'SISTEMAS', 'promedio': 75, 'clase': 'ALTA'}, 1643: {'nombre': 'GUILLERMO', 'edad': 22, 'carrera': 'ARQUITECTURA', 'promedio': 78, 'clase': 'ALTA'}, 1262: {'nombre': 'CARLOS', 'edad': 20, 'carrera': 'INFORMATICA', 'promedio': 80, 'clase': 'ALTA'}, 1505: {'nombre': 'ANDRES', 'edad': 21, 'carrera': 'SISTEMAS', 'promedio': 85, 'clase': 'MEDIA'}, 1955: {'nombre': 'GLORIA', 'edad': 25, 'carrera': 'INFORMATICA', 'promedio': 86, 'clase': 'ALTA'}, 1453: {'nombre': 'KAREN', 'edad': 18, 'carrera': 'INFORMATICA', 'promedio': 87, 'clase': 'MEDIA'}, 1968: {'nombre': 'GUILLE', 'edad': 20, 'carrera': 'TIC', 'promedio': 89, 'clase': 'BAJA'}, 1815: {'nombre': 'CRISTIAN', 'edad': 19, 'carrera': 'INFORMATICA', 'promedio': 83, 'clase': 'ALTA'}, 1356: {'nombre': 'JESSICA', 'edad': 24, 'carrera': 'ARQUITECTURA', 'promedio': 100, 'clase': 'BAJA'}, 1562: {'nombre': 'ELIZABETH', 'edad': 20, 'carrera': 'ARQUITECTURA', 'promedio': 94, 'clase': 'BAJA'}, 1060: {'nombre': 'MARCO', 'edad': 18, 'carrera': 'SISTEMAS', 'promedio': 80, 'clase': 'BAJA'}, 1973: {'nombre': 'KEVIN', 'edad': 22, 'carrera': 'SISTEMAS', 'promedio': 93, 'clase': 'MEDIA'}, 1765: {'nombre': 'RUBEN', 'edad': 19, 'carrera': 'QUIMICA', 'promedio': 72, 'clase': 'MEDIA'}, 1203: {'nombre': 'ELISA', 'edad': 24, 'carrera': 'TIC', 'promedio': 71, 'clase': 'ALTA'}, 1681: {'nombre': 'SUSANA', 'edad': 25, 'carrera': 'TIC', 'promedio': 91, 'clase': 'ALTA'}, 1461: {'nombre': 'JORGE', 'edad': 18, 'carrera': 'QUIMICA', 'promedio': 87, 'clase': 'MEDIA'}, 1369: {'nombre': 'DAVID', 'edad': 22, 'carrera': 'TIC', 'promedio': 98, 'clase': 'MEDIA'}, 1687: {'nombre': 'ELISA', 'edad': 25, 'carrera': 'TIC', 'promedio': 86, 'clase': 'ALTA'}, 1046: {'nombre': 'SARA', 'edad': 18, 'carrera': 'TIC', 'promedio': 80, 'clase': 'MEDIA'}, 1310: {'nombre': 'NANCY', 'edad': 24, 'carrera': 'TIC', 'promedio': 80, 'clase': 'BAJA'}, 1618: {'nombre': 'LUCY', 'edad': 20, 'carrera': 'INFORMATICA', 'promedio': 98, 'clase': 'MEDIA'}, 1393: {'nombre': 'DANIEL', 'edad': 25, 'carrera': 'QUIMICA', 'promedio': 91, 'clase': 'ALTA'}, 1017: {'nombre': 'MARCO', 'edad': 19, 'carrera': 'ARQUITECTURA', 'promedio': 87, 'clase': 'BAJA'}, 1874: {'nombre': 'EDUARDO', 'edad': 25, 'carrera': 'INFORMATICA', 'promedio': 81, 'clase': 'MEDIA'}, 1323: {'nombre': 'BRYANT', 'edad': 24, 'carrera': 'TIC', 'promedio': 77, 'clase': 'BAJA'}, 1252: {'nombre': 'JOSÉ', 'edad': 23, 'carrera': 'QUIMICA', 'promedio': 73, 'clase': 'BAJA'}, 1551: {'nombre': 'MICHELLE', 'edad': 25, 'carrera': 'SISTEMAS', 'promedio': 82, 'clase': 'BAJA'}, 1766: {'nombre': 'DONALD', 'edad': 21, 'carrera': 'ARQUITECTURA', 'promedio': 73, 'clase': 'ALTA'}, 1374: {'nombre': 'ROBERTO', 'edad': 25, 'carrera': 'TIC', 'promedio': 97, 'clase': 'ALTA'}, 1707: {'nombre': 'MARCO', 'edad': 20, 'carrera': 'ARQUITECTURA', 'promedio': 92, 'clase': 'BAJA'}, 1925: {'nombre': 'LUCY', 'edad': 19, 'carrera': 'INFORMATICA', 'promedio': 96, 'clase': 'ALTA'}, 1189: {'nombre': 'SARA', 'edad': 18, 'carrera': 'SISTEMAS', 'promedio': 99, 'clase': 'MEDIA'}, 1158: {'nombre': 'OSCAR', 'edad': 25, 'carrera': 'QUIMICA', 'promedio': 90, 'clase': 'BAJA'}, 1054: {'nombre': 'ELISA', 'edad': 18, 'carrera': 'INFORMATICA', 'promedio': 73, 'clase': 'ALTA'}, 1018: {'nombre': 'CRISTIAN', 'edad': 21, 'carrera': 'SISTEMAS', 'promedio': 99, 'clase': 'ALTA'}, 1479: {'nombre': 'KEVIN', 'edad': 21, 'carrera': 'ARQUITECTURA', 'promedio': 83, 'clase': 'MEDIA'}}

personas
# Out:
# {1392: {'nombre': 'EMILIA',
#   'edad': 25,
#   'carrera': 'ARQUITECTURA',
#   'promedio': 80,
#   'clase': 'BAJA'},
#  1584: {'nombre': 'EDUARDO',
#   'edad': 19,
#   'carrera': 'SISTEMAS',
#   'promedio': 90,
#   'clase': 'MEDIA'},
#  1858: {'nombre': 'EMILIA',
#   'edad': 22,
#   'carrera': 'TIC',
#   'promedio': 77,
#   'clase': 'ALTA'},
#  1652: {'nombre': 'MIGUEL',
#   'edad': 21,
#   'carrera': 'INFORMATICA',
#   'promedio': 72,
#   'clase': 'BAJA'},
#  1129: {'nombre': 'MARY',
#   'edad': 24,
#   'carrera': 'ARQUITECTURA',
#   'promedio': 80,
#   'clase': 'ALTA'},
#  1922: {'nombre': 'ELIZABETH',
#   'edad': 23,
#   'carrera': 'QUIMICA',
#   'promedio': 72,
#   'clase': 'ALTA'},
#  1550: {'nombre': 'LINDA',
#   'edad': 25,
#   'carrera': 'SISTEMAS',
#   'promedio': 95,
#   'clase': 'ALTA'},
#  1586: {'nombre': 'ANDRES',
#   'edad': 19,
#   'carrera': 'QUIMICA',
#   'promedio': 72,
#   'clase': 'ALTA'},
#  1143: {'nombre': 'ALFREDO',
#   'edad': 25,
#   'carrera': 'TIC',
# ...

# %%
personas.values()
# Out:
# dict_values([{'nombre': 'EMILIA', 'edad': 25, 'carrera': 'ARQUITECTURA', 'promedio': 80, 'clase': 'BAJA'}, {'nombre': 'EDUARDO', 'edad': 19, 'carrera': 'SISTEMAS', 'promedio': 90, 'clase': 'MEDIA'}, {'nombre': 'EMILIA', 'edad': 22, 'carrera': 'TIC', 'promedio': 77, 'clase': 'ALTA'}, {'nombre': 'MIGUEL', 'edad': 21, 'carrera': 'INFORMATICA', 'promedio': 72, 'clase': 'BAJA'}, {'nombre': 'MARY', 'edad': 24, 'carrera': 'ARQUITECTURA', 'promedio': 80, 'clase': 'ALTA'}, {'nombre': 'ELIZABETH', 'edad': 23, 'carrera': 'QUIMICA', 'promedio': 72, 'clase': 'ALTA'}, {'nombre': 'LINDA', 'edad': 25, 'carrera': 'SISTEMAS', 'promedio': 95, 'clase': 'ALTA'}, {'nombre': 'ANDRES', 'edad': 19, 'carrera': 'QUIMICA', 'promedio': 72, 'clase': 'ALTA'}, {'nombre': 'ALFREDO', 'edad': 25, 'carrera': 'TIC', 'promedio': 89, 'clase': 'BAJA'}, {'nombre': 'SARA', 'edad': 21, 'carrera': 'INFORMATICA', 'promedio': 97, 'clase': 'MEDIA'}, {'nombre': 'GUILLE', 'edad': 19, 'carrera': 'QUIMICA', 'promedio': 93, 'clase': '
# ...

# %%
from procesar_diccionarios import *

# %%
personas = crear_diccionario_personas(10)
personas
# Out:
# {1329: {'nombre': 'OSCAR',
#   'edad': 25,
#   'carrera': 'ARQUITECTURA',
#   'promedio': 86,
#   'clase': 'ALTA'},
#  1628: {'nombre': 'KAREN',
#   'edad': 21,
#   'carrera': 'ARQUITECTURA',
#   'promedio': 82,
#   'clase': 'BAJA'},
#  1504: {'nombre': 'ALFREDO',
#   'edad': 22,
#   'carrera': 'INFORMATICA',
#   'promedio': 74,
#   'clase': 'ALTA'},
#  1582: {'nombre': 'RANDY',
#   'edad': 20,
#   'carrera': 'QUIMICA',
#   'promedio': 95,
#   'clase': 'ALTA'},
#  1450: {'nombre': 'JORGE',
#   'edad': 25,
#   'carrera': 'INFORMATICA',
#   'promedio': 94,
#   'clase': 'BAJA'},
#  1064: {'nombre': 'MARGARITA',
#   'edad': 24,
#   'carrera': 'INFORMATICA',
#   'promedio': 95,
#   'clase': 'ALTA'},
#  1120: {'nombre': 'KEVIN',
#   'edad': 18,
#   'carrera': 'QUIMICA',
#   'promedio': 72,
#   'clase': 'BAJA'},
#  1544: {'nombre': 'PABLO',
#   'edad': 19,
#   'carrera': 'TIC',
#   'promedio': 99,
#   'clase': 'ALTA'},
#  1260: {'nombre': 'ELISA',
#   'edad': 23,
#   'carrera': 'QUIMICA',
# ...

# %%
# Nombres de las claves

nombres_claves = personas.keys()
nombres_claves
# Out:
# dict_keys([1329, 1628, 1504, 1582, 1450, 1064, 1120, 1544, 1260, 1410])

# %%
# Nombre de las claves internas en el diccionario anidado personas
for clave1 in personas:
    for clave2 in personas[clave1]:
        print(clave2)
    break;
# Out:
# nombre
# edad
# carrera
# promedio
# clase
